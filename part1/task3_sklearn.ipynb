# %% [markdown]
# <a href="https://colab.research.google.com/github/ermoshinav/data_science_stepik/blob/main/part1/task3_sklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Скачайте набор данных с тремя переменными: sex, exang, num. Представьте, что при помощи дерева решений мы хотим классифицировать есть или нет у пациента заболевание сердца (переменная num), основываясь на двух признаках: пол (sex) и наличие/отсутсвие стенокардии (exang). Обучите дерево решений на этих данных, используйте entropy в качестве критерия.

# %%
import pandas as pd
import sklearn.tree

# %%
dt = pd.read_csv('https://stepik.org/media/attachments/course/4852/train_data_tree.csv')

# %%
y= dt.num
X= dt[['sex','exang']]

# %%
clf = sklearn.tree.DecisionTreeClassifier(criterion = 'entropy')
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
sklearn.tree.plot_tree(clf, filled=True)
# Out:
# [Text(0.5, 0.8333333333333334, 'x[1] <= 0.5\nentropy = 0.996\nsamples = 238\nvalue = [128, 110]'),
#  Text(0.25, 0.5, 'x[0] <= 0.5\nentropy = 0.903\nsamples = 157\nvalue = [107, 50]'),
#  Text(0.125, 0.16666666666666666, 'entropy = 0.612\nsamples = 53\nvalue = [45, 8]'),
#  Text(0.375, 0.16666666666666666, 'entropy = 0.973\nsamples = 104\nvalue = [62, 42]'),
#  Text(0.75, 0.5, 'x[0] <= 0.5\nentropy = 0.826\nsamples = 81\nvalue = [21, 60]'),
#  Text(0.625, 0.16666666666666666, 'entropy = 0.954\nsamples = 16\nvalue = [6, 10]'),
#  Text(0.875, 0.16666666666666666, 'entropy = 0.779\nsamples = 65\nvalue = [15, 50]')]
